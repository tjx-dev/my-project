# %%
#Model i/O 跟模型对话

import os
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(
    model="deepseek-v4-pro",  # 直接传入类
    api_key=os.environ.get("DEEPSEEK_API_KEY"),
    base_url="https://api.deepseek.com"
)
print(type(llm))
# Out:
# <class 'langchain_openai.chat_models.base.ChatOpenAI'>
